# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# PEPSU = 'https://www.redbus.in/online-booking/pepsu/?utm_source=rtchometile'
# CTU = 'https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu'
# ASTC = 'https://www.redbus.in/online-booking/astc/?utm_source=rtchometile'
# KLTC = 'https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile'
# BSRTC = 'https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc/?utm_source=rtchometile'

# %% [markdown]
# PEPSU

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/pepsu/?utm_source=rtchometile'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Patiala to Delhi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Delhi to Patiala, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Ludhiana to Delhi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Delhi to Ludhiana, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Jalandhar to Delhi Airport, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Ludhiana to Delhi Airport, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Jalandhar to Delhi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Delhi Airport to Patiala, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Delhi Airport to Ludhiana, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Delhi to Jalandhar, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#              Route_Name                                         Route_Link  \
# 0      Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 1      Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 2      Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 3      Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 4      Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# ..                  ...                                                ...
# 537  Delhi to Jalandhar  https://www.redbus.in/bus-tickets/delhi-to-jal...
# 538  Delhi to Jalandhar  https://www.redbus.in/bus-tickets/delhi-to-jal...
# 539  Delhi to Jalandhar  https://www.redbus.in/bus-tickets/delhi-to-jal...
# 540  Delhi to Jalandhar  https://www.redbus.in/bus-tickets/delhi-to-jal...
# 541  Delhi to Jalandhar  https://www.redbus.in/bus-tickets/delhi-to-jal...
#
#                             Bus_Name                         Bus_Type  \
# 0    Indo Canadian Transport Company  Mercedes A/C Semi Sleeper (2+2)
# 1    Indo Canadian Transport Company          Volvo A/C Sleeper (2+1)
# 2    Indo Canadian Transport Company  Mercedes A/C Semi Sleeper (2+2)
# 3    Indo Canadian Transport Company  Mercedes A/C Semi Sleeper (2+2)
# 4    Indo Canadian Transport Company  Mercedes A/C Semi Sleeper (2+2)
# ..                               ...                              ...
# 537                          Big Bus       A/C Seater / Sleeper (2+2)
# 538                       MM Travels       A/C Seater / Sleeper (2+2)
# 539              Maheshwaram Travels       A/C Seater / Sleeper (2+2)
# 540                       MM Travels       A/C Seater / Sleeper (2+2)
# 541               Ram Dalal Holidays    Bharat Benz A/C Sleeper (2+1)
#
#     Departure_Time Duration Reaching_Time Star_Rating     Price  \
# 0            00:00  07h 00m         07:00         3.9  INR 3300
# 1            01:59  07h 00m         08:59         3.9  INR 3850
# 2            04:00  07h 00m         11:00         3.9  INR 3300
# 3            06:00  07h 00m         13:00         3.9  INR 3300
# 4            08:00  07h 00m         15:00         3.9  INR 3300
# ..             ...      ...           ...         ...       ...
# 537          23:25  06h 20m         05:45         1.0      1849
# 538          11:10  09h 15m         20:25         1.0  INR 4000
# 539          10:10  18h 55m         05:05           0   INR 666
# 540          11:10  09h 15m         20:25           0  INR 4000
# 541          22:30  08h 00m         06:30           0   INR 999
#
#       Seat_Availability
# 0    47 Seats available
# 1    31 Seats available
# 2    44 Seats available
# 3    47 Seats available
# 4    36 Seats available
# ..                  ...
# 537    1 Seat available
# 538  50 Seats available
# 539  39 Seats available
# 540  52 Seats available
# 541  44 Seats available
#
# [542 rows x 10 columns]

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\PEPSU.csv",index=False)

# %% [markdown]
# CTU

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Yamuna Nagar to Chandigarh, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Chandigarh to Delhi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page
# ..            ...         ...       ...                 ...
# 149         04:30         3.7  INR 1199  36 Seats available
# 150         01:45         1.6   INR 749  37 Seats available
# 151         04:00         3.7  INR 1099  26 Seats available
# 152         00:45         3.6      2970  26 Seats available
# 153         01:45           0      2970  26 Seats available
#
# [154 rows x 10 columns]

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\CTU.csv",index=False)

# %% [markdown]
# ASTC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/astc/?utm_source=rtchometile'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Tezpur to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Tezpur, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Nagaon (Assam) to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Nagaon (Assam), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Goalpara to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Jorhat to North Lakhimpur, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Dhubri, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Dhubri to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page North Lakhimpur to Sibsagar (Assam), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page North Lakhimpur to Jorhat, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 2: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 5: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                     Route_Name  \
# 0           Tezpur to Guwahati
# 1           Tezpur to Guwahati
# 2           Tezpur to Guwahati
# 3           Tezpur to Guwahati
# 4           Tezpur to Guwahati
# 5           Guwahati to Tezpur
# 6           Guwahati to Tezpur
# 7           Guwahati to Tezpur
# 8           Guwahati to Tezpur
# 9           Guwahati to Tezpur
# 10          Guwahati to Tezpur
# 11          Guwahati to Tezpur
# 12          Guwahati to Tezpur
# 13          Guwahati to Tezpur
# 14          Guwahati to Tezpur
# 15          Guwahati to Tezpur
# 16          Guwahati to Tezpur
# 17          Guwahati to Tezpur
# 18          Guwahati to Tezpur
# 19          Guwahati to Tezpur
# 20  Nagaon (Assam) to Guwahati
# 21  Guwahati to Nagaon (Assam)
# 22  Guwahati to Nagaon (Assam)
# 23  Guwahati to Nagaon (Assam)
# 24          Dhubri to Guwahati
#
#                                            Route_Link  \
# 0   https://www.redbus.in/bus-tickets/tezpur-to-gu...
#
# 10       NON AC Seater/ Sleeper (2+1)          20:30  04h 30m         01:00
# 11         A/C Seater / Sleeper (2+1)          20:45  05h 45m         02:30
# 12               NON A/C Seater (2+1)          21:30  04h 30m         02:00
# 13               NON A/C Seater (2+1)          21:45  04h 15m         02:00
# 14       Bharat Benz A/C Seater (2+1)          21:30  05h 00m         02:30
# 15               NON A/C Seater (2+1)          17:30  05h 30m         23:00
# 16               NON A/C Seater (2+1)          18:00  05h 30m         23:30
# 17  NON A/C Seater Semi Sleeper (2+1)          20:00  05h 15m         01:15
# 18               NON A/C Seater (2+1)          18:45  05h 00m         23:45
# 19                   A/C Seater (2+1)          20:40  03h 50m         00:30
# 20       Volvo AC Seater Pushback 2+2          17:00  02h 15m         19:15
# 21               NON A/C Seater (2+1)          17:30  03h 10m         20:40
# 22               NON A/C Seater (2+1)          18:45  03h 15m         22:00
# 23                   A/C Seater (2+1)          21:15  02h 35m         23:50
# 24                Non AC Seater (2+2)          20:15  07h 15m         03:30
#
#    Star_Rating       Price   Seat_Availability
# 0          4.2     INR 298  11 Seats available
# 1          4.6  INR 397.08   2 Seats available
# 2          3.4     INR 450  27 Seats available
# 3          4.0         450  19 Seats available
# 4          2.7     INR 600  31 Seats available
# 5          4.3     INR 360  25 Seats available
# 6          4.7         351  31 Seats available
# 7          3.5         450  18 Seats available
# 8          3.4         495  24 Seats available
# 9          3.4         450  24 Seats available
# 10         4.3         450  25 Seats available
# 11         3.5         450  24 Seats available
# 12         3.5         405  28 Seats available
# 13         3.0         405  12 Seats available
# 14         4.2         475  11 Seats available
# 15         2.1         459  25 Seats available
# 16         2.9         350  15 Seats available
# 17         2.8         450  10 Seats available
# 18         2.1         451  24 Seats available
# 19         2.2         500  18 Seats available
# 20         4.4  INR 283.63   2 Seats available
# 21         2.1         356  19 Seats available
# 22         2.1         341  24 Seats available
# 23         4.6         550  26 Seats available
# 24         2.3     INR 350  40 Seats available

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\ASTC.csv",index=False)

# %% [markdown]
# KLTC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Pune to Goa, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Goa to Pune, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Mumbai to Goa, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Bangalore to Goa, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Goa to Bangalore, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Belagavi to Goa, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Goa to Mumbai, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Goa to Belagavi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Goa to Kolhapur(Maharashtra), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Pandharpur to Goa, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 4: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 5: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                        Route_Name  \
# 0                     Pune to Goa
# 1                     Pune to Goa
# 2                     Pune to Goa
# 3                     Pune to Goa
# 4                     Pune to Goa
# ..                            ...
# 409  Goa to Kolhapur(Maharashtra)
# 410  Goa to Kolhapur(Maharashtra)
# 411  Goa to Kolhapur(Maharashtra)
# 412             Pandharpur to Goa
# 413             Pandharpur to Goa
#
#                                             Route_Link  \
# 0        https://www.redbus.in/bus-tickets/pune-to-goa
# 1        https://www.redbus.in/bus-tickets/pune-to-goa
# 2        https://www.redbus.in/bus-tickets/pune-to-goa
# 3        https://www.redbus.in/bus-tickets/pune-to-goa
# 4        https://www.redbus.in/bus-tickets/pune-to-goa
# ..                                                 ...
# 409  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 410  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 411  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 412  https://www.redbus.in/bus-tickets/pandharpur-t...
# 413  https://www.redbus.in/bus-tickets/pandharpur-t...
#
#                                               Bus_Name  \
# 0                                        Atmaram Gobus
# 1                                  Gogte Anand Travels
# 2                              Ashray National Express
# 3                                  AdIntrCity SmartBus
# 4                            Dolphin Travel House (37)
# ..                                                 ...
# 409                     New Shivbaba Tours And Travels
# 410                                    AAINATH TRAVELS
# 411                          Atmaram Travels (Dolphin)
# 412  Kadamba Transport Corporation Limited (KTCL) -...
# 413                     New Shivbaba Tours And Travels
#
#                                        Bus_Type Departure_Time Duration  \
# 0                          VE A/C Sleeper (2+1)          21:00  10h 30m
# 1    Volvo Multi-Axle I-Shift A/C Sleeper (2+1)          21:15  10h 40m
# 2                         NON A/C Sleeper (2+1)          20:00  10h 45m
# 3                              AC Sleeper (2+1)          22:15  11h 25m
# 4                 Bharat Benz A/C Sleeper (2+1)          19:45  10h 15m
# ..                                          ...            ...      ...
# 409                            AC Sleeper (2+1)          19:45  05h 05m
# 410                           A/C Sleeper (2+1)          21:30  05h 00m
# 411                           A/C Sleeper (2+1)          22:15  06h 44m
# 412                           Non AC Seater 2+2          21:15  12h 45m
# 413                            AC Sleeper (2+1)          19:45  10h 15m
#
#     Reaching_Time Star_Rating     Price   Seat_Availability
# 0           07:30         4.8  INR 1799   2 Seats available
# 1           07:55         4.1  INR 1399    1 Seat available
# 2           06:45         4.3  INR 1200   3 Seats available
# 3           09:40         4.4  INR 1746   5 Seats available
# 4           06:00         4.2  INR 2000   6 Seats available
# ..            ...         ...       ...                 ...
# 409         00:50         2.0       949  14 Seats available
# 410         02:30         2.0   INR 900  19 Seats available
# 411         04:59         2.8  INR 1099  24 Seats available
# 412         10:00         3.2   INR 735   2 Seats available
# 413         06:00         2.7       949  16 Seats available
#
# [414 rows x 10 columns]

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\KLTC.csv",index=False)

# %% [markdown]
# BSRTC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc/?utm_source=rtchometile'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Patna (Bihar) to Motihari, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Gopalganj (Bihar) to Delhi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Patna (Bihar) to Bettiah, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Bettiah to Patna (Bihar), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Motihari to Delhi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Delhi to Motihari, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Balmiki Nagar (bihar) to Patna (Bihar), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Patna (Bihar) to Katihar, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Patna (Bihar) to Balmiki Nagar (bihar), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Patna (Bihar) to Ranchi, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                                 Route_Name  \
# 0                Patna (Bihar) to Motihari
# 1                Patna (Bihar) to Motihari
# 2                Patna (Bihar) to Motihari
# 3                Patna (Bihar) to Motihari
# 4               Gopalganj (Bihar) to Delhi
# 5               Gopalganj (Bihar) to Delhi
# 6               Gopalganj (Bihar) to Delhi
# 7               Gopalganj (Bihar) to Delhi
# 8               Gopalganj (Bihar) to Delhi
# 9               Gopalganj (Bihar) to Delhi
# 10              Gopalganj (Bihar) to Delhi
# 11              Gopalganj (Bihar) to Delhi
# 12              Gopalganj (Bihar) to Delhi
# 13              Gopalganj (Bihar) to Delhi
# 14              Gopalganj (Bihar) to Delhi
# 15              Gopalganj (Bihar) to Delhi
# 16                Patna (Bihar) to Bettiah
# 17                Patna (Bihar) to Bettiah
# 18                Patna (Bihar) to Bettiah
# 55               A/C Seater/Sleeper (2+1)          20:20  08h 25m
# 56             A/C Seater / Sleeper (2+2)          20:00  09h 00m
# 57                    Non AC Seater (2+2)          21:30  08h 00m
#
#    Reaching_Time Star_Rating     Price   Seat_Availability
# 0          01:00         4.3   INR 230  21 Seats available
# 1          21:31         1.2  INR 1999  36 Seats available
# 2          21:35         2.8       808  16 Seats available
# 3          23:30         1.1       450   4 Seats available
# 4          10:00         2.2      1619   5 Seats available
# 5          08:30         2.6  INR 1096  13 Seats available
# 6          10:50         2.3      2469  35 Seats available
# 7          10:00         2.0  INR 3250  30 Seats available
# 8          14:30         1.2  INR 1899  71 Seats available
# 9          09:00         1.4  INR 2499  16 Seats available
# 10         08:00         1.4  INR 2499  14 Seats available
# 11         08:10         1.4  INR 2499  30 Seats available
# 12         08:30         1.4  INR 2499  14 Seats available
# 13         08:30         1.4  INR 2499  14 Seats available
# 14         08:00         1.4  INR 2499  14 Seats available
# 15         07:15         1.0  INR 1599  35 Seats available
# 16         03:40         3.9   INR 350  21 Seats available
# 17         05:00         4.1       495  28 Seats available
# 18         04:00         3.4       405  26 Seats available
# 19         02:00         1.9       450   4 Seats available
# 20         02:00         2.8   INR 285  24 Seats available
# 21         03:06           0   INR 285  28 Seats available
# 22         10:50         1.6      2469  35 Seats available
# 23         12:45         1.0  INR 1900  39 Seats available
# 24         03:06           0   INR 403  28 Seats available
# 25         06:30         3.6   INR 468   2 Seats available
# 26         05:05         1.8   INR 750  14 Seats available
# 27         06:05         1.6   INR 800  33 Seats available
# 28         06:00         1.7       450   4 Seats available
# 29         07:00         1.8       405  26 Seats available
# 30         06:00         3.0   INR 525  22 Seats available
# 31         04:15         4.3       900  12 Seats available
# 32         06:45         4.0       808  13 Seats available
# 33         06:00         4.0   INR 580  15 Seats available
# 34         05:00         4.6       698  18 Seats available
# 35         05:30         4.2       459  15 Seats available
# 36         06:00         3.0   INR 800  10 Seats available
# 37         04:10         3.0   INR 700  16 Seats available
# 38         04:45         3.9       698  31 Seats available
# 39         05:30         3.4       475  28 Seats available
# 40         04:00         2.8       925   7 Seats available
# 41         04:20         1.9       900  41 Seats available
# 42         05:30         2.3       540  26 Seats available
# 43         06:00         1.9  INR 1100   4 Seats available
# 44         05:40         2.9       540  22 Seats available
# 45         05:30         1.9  INR 1100   4 Seats available
# 46         06:00         1.9  INR 1799   2 Seats available
# 47         03:45         2.0       613  34 Seats available
# 48         04:30         1.4   INR 500  19 Seats available
# 49         05:40         2.9       620  35 Seats available
# 50         04:25         1.9       990  19 Seats available
# 51         03:00         2.9   INR 550  13 Seats available
# 52         04:00         2.9   INR 700    1 Seat available
# 53         05:30         1.0   INR 699  17 Seats available
# 54         03:15         1.8       555  28 Seats available
# 55         04:45         1.4   INR 949  14 Seats available
# 56         05:00         1.4  INR 1000  50 Seats available
# 57         05:30         1.9   INR 999  41 Seats available

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\BSRTC.csv",index=False)
