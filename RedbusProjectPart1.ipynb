# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# Bus routes Link,Bus route Name, Bus name, Bus Type(Sleeper/Seater),  Departing Time, Duration, Reaching_Time, Star-rating, Price, Seat_availability.

# %% [markdown]
# links
#
# JKSRTC = 'https://www.redbus.in/online-booking/jksrtc'
# KAAC = 'https://www.redbus.in/online-booking/kaac-transport'
# WBSRTC = 'https://www.redbus.in/online-booking/west-bengal-transport-corporation?utm_source=rtchometile'
# NBSTC = 'https://www.redbus.in/travels/nbstc'
# WBTC = 'https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile'

# %% [markdown]
# JKSRTC - Jammu and Kashmir State Road Transport Corporation

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/jksrtc'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Delhi to Srinagar, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Jammu (j and k) to Katra (jammu and kashmir), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Katra (jammu and kashmir) to Jammu (j and k), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 4: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                                       Route_Name  \
# 0                              Delhi to Srinagar
# 1                              Delhi to Srinagar
# 2                              Delhi to Srinagar
# 3                              Delhi to Srinagar
# 4   Jammu (j and k) to Katra (jammu and kashmir)
# 5   Jammu (j and k) to Katra (jammu and kashmir)
# 6   Jammu (j and k) to Katra (jammu and kashmir)
# 7   Jammu (j and k) to Katra (jammu and kashmir)
# 8   Jammu (j and k) to Katra (jammu and kashmir)
# 9   Jammu (j and k) to Katra (jammu and kashmir)
# 10  Jammu (j and k) to Katra (jammu and kashmir)
# 11  Jammu (j and k) to Katra (jammu and kashmir)
# 12  Jammu (j and k) to Katra (jammu and kashmir)
# 13  Jammu (j and k) to Katra (jammu and kashmir)
# 14  Jammu (j and k) to Katra (jammu and kashmir)
# 15  Jammu (j and k) to Katra (jammu and kashmir)
# 16  Jammu (j and k) to Katra (jammu and kashmir)
# 17  Jammu (j and k) to Katra (jammu and kashmir)
# 18  Jammu (j and k) to Katra (jammu and kashmir)
# 19  Jammu (j and k) to Katra (jammu and kashmir)
# 20  Jammu (j and k) to Katra (jammu and kashmir)
# 21  Jammu (j and k) to Katra (jammu and kashmir)
# 22  Jammu (j and k) to Katra (jammu and kashmir)
# 23  Jammu (j and k) to Katra (jammu and kashmir)
# 24  Jammu (j and k) to Katra (jammu and kashmir)
# 25  Jammu (j and k) to Katra (jammu and kashmir)
# 26  Jammu (j and k) to Katra (jammu and kashmir)
# 27  Jammu (j and k) to Katra (jammu and kashmir)
# 28  Jammu (j and k) to Katra (jammu and kashmir)
# 29  Jammu (j and k) to Katra (jammu and kashmir)
# 30  Jammu (j and k) to Katra (jammu and kashmir)
# 31  Katra (jammu and kashmir) to Jammu (j and k)
# 32  Katra (jammu and kashmir) to Jammu (j and k)
# 33  Katra (jammu and kashmir) to Jammu (j and k)
# 34  Katra (jammu and kashmir) to Jammu (j and k)
# 35  Katra (jammu and kashmir) to Jammu (j and k)
# 36  Katra (jammu and kashmir) to Jammu (j and k)
# 37  Katra (jammu and kashmir) to Jammu (j and k)
# 38  Katra (jammu and kashmir) to Jammu (j and k)
# 39  Katra (jammu and kashmir) to Jammu (j and k)
# 40  Katra (jammu and kashmir) to Jammu (j and k)
# 41  Katra (jammu and kashmir) to Jammu (j and k)
# 42  Katra (jammu and kashmir) to Jammu (j and k)
# 43  Katra (jammu and kashmir) to Jammu (j and k)
# 44  Katra (jammu and kashmir) to Jammu (j and k)
# 45  Katra (jammu and kashmir) to Jammu (j and k)
# 46  Katra (jammu and kashmir) to Jammu (j and k)
# 47  Katra (jammu and kashmir) to Jammu (j and k)
# 48  Katra (jammu and kashmir) to Jammu (j and k)
# 49  Katra (jammu and kashmir) to Jammu (j and k)
# 50  Katra (jammu and kashmir) to Jammu (j and k)
# 51  Katra (jammu and kashmir) to Jammu (j and k)
# 52  Katra (jammu and kashmir) to Jammu (j and k)
#
#                                            Route_Link  \
# 0   https://www.redbus.in/bus-tickets/delhi-to-sri...
# 1   https://www.redbus.in/bus-tickets/delhi-to-sri...
# 2   https://www.redbus.in/bus-tickets/delhi-to-sri...
# 3   https://www.redbus.in/bus-tickets/delhi-to-sri...
# 4    https://www.redbus.in/bus-tickets/jammu-to-katra
# 5    https://www.redbus.in/bus-tickets/jammu-to-katra
# 6    https://www.redbus.in/bus-tickets/jammu-to-katra
# 7    https://www.redbus.in/bus-tickets/jammu-to-katra
# 8    https://www.redbus.in/bus-tickets/jammu-to-katra
# 9    https://www.redbus.in/bus-tickets/jammu-to-katra
# 10   https://www.redbus.in/bus-tickets/jammu-to-katra
# 11   https://www.redbus.in/bus-tickets/jammu-to-katra
# 12   https://www.redbus.in/bus-tickets/jammu-to-katra
# 13   https://www.redbus.in/bus-tickets/jammu-to-katra
# 14   https://www.redbus.in/bus-tickets/jammu-to-katra
# 15   https://www.redbus.in/bus-tickets/jammu-to-katra
# 16   https://www.redbus.in/bus-tickets/jammu-to-katra
# 17   https://www.redbus.in/bus-tickets/jammu-to-katra
# 27  SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)
# 28                                  City Land Travels
# 29  SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)
# 30                                    Perfect Holiday
# 31                                     JKRTC - 169884
# 32                             Orbit Aviation Pvt Ltd
# 33                             Vijay Tour and Travels
# 34                             Vijay Tour and Travels
# 35                                            FlixBus
# 36                                       Zingbus Plus
# 37                                  City Land Travels
# 38                                   KN Nehra Travels
# 39                                       Zingbus Plus
# 40                                            FlixBus
# 41                                    New Pal Travels
# 42                                       Royal Golden
# 43                        Golden Temple Express Volvo
# 44                                     Lavish Travels
# 45                                    Perfect Holiday
# 46                                       Royal Golden
# 47  SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)
# 48  SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)
# 49                                     Namdev Travels
# 50                                          SPEED BUS
# 51                                            VGO BUS
# 52                                    Perfect Holiday
#
#                                   Bus_Type Departure_Time Duration  \
# 0                        A/C Sleeper (2+1)          21:35  19h 50m
# 1    Bharat Benz A/C Seater /Sleeper (2+1)          20:00  19h 20m
# 2                         AC Sleeper (2+1)          15:00  17h 00m
# 3               A/C Seater / Sleeper (2+2)          21:15  18h 15m
# 4               A/C Seater Executive (2+1)          07:30  01h 00m
# 5   Mercedes Multi-Axle Semi Sleeper (2+2)          02:55  00h 30m
# 6                        A/C Sleeper (2+2)          03:45  02h 00m
# 7                        A/C Sleeper (2+2)          05:00  02h 00m
# 8               A/C Seater / Sleeper (2+2)          05:00  01h 00m
# 9               A/C Seater / Sleeper (2+2)          05:00  01h 30m
# 10                A/C Seater/Sleeper (2+1)          07:00  01h 00m
# 11           VE A/C Seater / Sleeper (2+1)          07:20  00h 50m
# 12   Bharat Benz A/C Seater /Sleeper (2+1)          06:15  04h 55m
# 13                       A/C Sleeper (2+1)          07:20  04h 35m
# 14              A/C Seater / Sleeper (2+2)          19:50  01h 40m
# 15              A/C Seater / Sleeper (2+2)          20:00  01h 45m
# 16              A/C Seater / Sleeper (2+2)          01:00  04h 00m
# 17              A/C Seater / Sleeper (2+2)          01:15  04h 00m
# 18           Bharat Benz A/C Sleeper (2+1)          06:55  01h 20m
# 19  Bharat Benz A/C Seater / Sleeper (2+2)          06:00  01h 30m
# 20           Bharat Benz A/C Sleeper (2+1)          11:40  01h 35m
# 21                    NON A/C Seater (2+2)          16:00  02h 00m
# 22                 Volvo A/C Sleeper (2+2)          08:00  01h 00m
# 23   Bharat Benz A/C Seater /Sleeper (2+1)          06:00  01h 30m
# 24           VE A/C Seater / Sleeper (2+1)          08:20  00h 50m
# 25              A/C Seater / Sleeper (2+2)          08:40  00h 50m
# 26                 Volvo A/C Sleeper (2+2)          06:15  01h 30m
# 27                       A/C Sleeper (2+2)          09:15  00h 55m
# 28                A/C Seater/Sleeper (2+1)          09:30  01h 20m
# 29                       A/C Sleeper (2+2)          09:30  01h 00m
# 30              A/C Seater / Sleeper (2+2)          07:00  01h 00m
# 31              A/C Seater Executive (2+1)          12:00  01h 00m
# 36         20:10         4.4      INR 100  39 Seats available
# 37         20:30         3.6          709  28 Seats available
# 38         20:30         3.0          899  30 Seats available
# 39         21:20         4.4      INR 120  31 Seats available
# 40         22:25         4.2   INR 659.82  26 Seats available
# 41         00:30         3.6      INR 499  46 Seats available
# 42         14:00         1.9          675  36 Seats available
# 43         15:15         1.2          399  32 Seats available
# 44         04:35         2.9          809  52 Seats available
# 45         22:15         2.5          899  42 Seats available
# 46         00:00         1.9          495  32 Seats available
# 47         20:00         3.7          989  38 Seats available
# 48         21:00         3.7          989  48 Seats available
# 49         20:30         3.4      INR 100  34 Seats available
# 50         17:17         4.0         1663  52 Seats available
# 51         19:30         2.5     INR 1800  40 Seats available
# 52         21:25           0         1709  42 Seats available

# %%
df.isnull().sum()
# Out:
# Route_Name           0
# Route_Link           0
# Bus_Name             0
# Bus_Type             0
# Departure_Time       0
# Duration             0
# Reaching_Time        0
# Star_Rating          0
# Price                0
# Seat_Availability    0
# dtype: int64

# %%
df['Bus_Type'].unique()
# Out:
# array(['A/C Sleeper (2+1)', 'Bharat Benz A/C Seater /Sleeper (2+1)',
#        'AC Sleeper (2+1)', 'A/C Seater / Sleeper (2+2)',
#        'A/C Seater Executive (2+1)',
#        'Mercedes Multi-Axle Semi Sleeper (2+2)', 'A/C Sleeper (2+2)',
#        'A/C Seater/Sleeper (2+1)', 'VE A/C Seater / Sleeper (2+1)',
#        'Bharat Benz A/C Sleeper (2+1)',
#        'Bharat Benz A/C Seater / Sleeper (2+2)', 'NON A/C Seater (2+2)',
#        'Volvo A/C Sleeper (2+2)', 'A/C Seater / Sleeper (2+1)'],
#       dtype=object)

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))

# %%
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\JKSRTC.csv",index=False)

# %% [markdown]
# KAAC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/kaac-transport'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Diphu to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Diphu, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Bokolia (assam) to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Langhin (assam) to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Dokmoka to Guwahati, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Bokolia (assam), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Dokmoka, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Langhin (assam), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Guwahati to Manja (assam), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Diphu to Hamren, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 4: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 5: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                      Route_Name  \
# 0             Diphu to Guwahati
# 1             Diphu to Guwahati
# 2             Diphu to Guwahati
# 3             Diphu to Guwahati
# 4             Guwahati to Diphu
# 5             Guwahati to Diphu
# 6             Guwahati to Diphu
# 7             Guwahati to Diphu
# 8   Bokolia (assam) to Guwahati
# 9   Bokolia (assam) to Guwahati
# 10  Bokolia (assam) to Guwahati
# 11  Bokolia (assam) to Guwahati
# 12  Langhin (assam) to Guwahati
# 13  Langhin (assam) to Guwahati
# 14  Langhin (assam) to Guwahati
# 15  Langhin (assam) to Guwahati
# 16          Dokmoka to Guwahati
# 17          Dokmoka to Guwahati
# 18          Dokmoka to Guwahati
# 19          Dokmoka to Guwahati
# 20  Guwahati to Bokolia (assam)
# 21  Guwahati to Bokolia (assam)
# 22  Guwahati to Bokolia (assam)
# 23  Guwahati to Bokolia (assam)
# 24          Guwahati to Dokmoka
# 25          Guwahati to Dokmoka
# 26          Guwahati to Dokmoka
# 27          Guwahati to Dokmoka
# 28  Guwahati to Langhin (assam)
# 29  Guwahati to Langhin (assam)
# 30  Guwahati to Langhin (assam)
# 31  Guwahati to Langhin (assam)
# 32    Guwahati to Manja (assam)
# 33    Guwahati to Manja (assam)
# 34    Guwahati to Manja (assam)
# 35    Guwahati to Manja (assam)
#
#                                            Route_Link  \
# 0   https://www.redbus.in/bus-tickets/diphu-to-guw...
# 1   https://www.redbus.in/bus-tickets/diphu-to-guw...
# 2   https://www.redbus.in/bus-tickets/diphu-to-guw...
# 3   https://www.redbus.in/bus-tickets/diphu-to-guw...
# 4   https://www.redbus.in/bus-tickets/guwahati-to-...
# 5   https://www.redbus.in/bus-tickets/guwahati-to-...
# 6   https://www.redbus.in/bus-tickets/guwahati-to-...
# 7   https://www.redbus.in/bus-tickets/guwahati-to-...
# 8   https://www.redbus.in/bus-tickets/bokolia-assa...
# 9   https://www.redbus.in/bus-tickets/bokolia-assa...
# 10  https://www.redbus.in/bus-tickets/bokolia-assa...
# 11  https://www.redbus.in/bus-tickets/bokolia-assa...
# 12  https://www.redbus.in/bus-tickets/langhin-assa...
# 13  https://www.redbus.in/bus-tickets/langhin-assa...
# 14  https://www.redbus.in/bus-tickets/langhin-assa...
# 15  https://www.redbus.in/bus-tickets/langhin-assa...
# 16  https://www.redbus.in/bus-tickets/dokmoka-to-g...
# 17  https://www.redbus.in/bus-tickets/dokmoka-to-g...
# 18  https://www.redbus.in/bus-tickets/dokmoka-to-g...
# 32  KAAC TRANSPORT - 157250             Non AC Seater 2+2          11:30
# 33           Kareng Travels           Non AC Seater (2+2)          11:45
# 34           Kareng Travels              A/C Seater (2+1)          09:30
# 35           Kareng Travels           Non AC Seater (2+1)          05:00
#
#    Duration Reaching_Time Star_Rating    Price   Seat_Availability
# 0   05h 30m         09:30         4.4      361  44 Seats available
# 1   05h 00m         09:30         3.9      361  45 Seats available
# 2   06h 00m         16:00         4.4  INR 400  33 Seats available
# 3   05h 30m         16:45         4.3  INR 380  35 Seats available
# 4   06h 15m         17:45         4.3      361  44 Seats available
# 5   06h 00m         11:00         4.2  INR 380  37 Seats available
# 6   06h 45m         16:15         4.4  INR 400  26 Seats available
# 7   06h 45m         18:30         4.6      361  41 Seats available
# 8   04h 30m         09:30         3.9  INR 299  44 Seats available
# 9   04h 45m         16:00         4.4  INR 300  33 Seats available
# 10  04h 30m         16:45         4.0  INR 300  37 Seats available
# 11  04h 00m         09:30         3.5      285  45 Seats available
# 12  04h 00m         09:30         4.1  INR 266  44 Seats available
# 13  04h 15m         16:45         4.4  INR 300  37 Seats available
# 14  03h 45m         09:30         4.3      285  45 Seats available
# 15  04h 30m         16:00         3.7  INR 300  37 Seats available
# 16  03h 45m         09:30         4.3  INR 250  44 Seats available
# 17  03h 30m         09:30         4.3      266  45 Seats available
# 18  04h 15m         16:00         4.4  INR 300  37 Seats available
# 19  03h 45m         16:45         4.5  INR 280  37 Seats available
# 20  04h 15m         15:45         3.4  INR 299  44 Seats available
# 21  05h 15m         14:45         4.3  INR 300  26 Seats available
# 22  04h 45m         16:30         4.4  INR 300  43 Seats available
# 23  04h 45m         09:45         4.2  INR 300  37 Seats available
# 24  03h 15m         14:45         4.7  INR 250  44 Seats available
# 25  04h 00m         09:00         4.7  INR 280  37 Seats available
# 26  04h 30m         14:00         4.5  INR 300  27 Seats available
# 27  04h 15m         16:00         4.4  INR 280  43 Seats available
# 28  03h 30m         15:00         4.2  INR 266  44 Seats available
# 29  04h 30m         16:15         3.9  INR 300  41 Seats available
# 30  04h 45m         14:15         4.0  INR 300  28 Seats available
# 31  04h 30m         09:30         4.0  INR 300  37 Seats available
# 32  05h 30m         17:00         4.7  INR 350  44 Seats available
# 33  06h 15m         18:00         4.4  INR 360  45 Seats available
# 34  06h 15m         15:45         3.8  INR 400  31 Seats available
# 35  05h 30m         10:30         3.2  INR 360  37 Seats available

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\KAAC.csv",index=False)

# %% [markdown]
# WBSRTC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/west-bengal-transport-corporation?utm_source=rtchometile'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Kolkata to Digha, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Digha to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Mandarmani to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Kolkata to Mandarmani, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                 Route_Name                                         Route_Link  \
# 0         Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 1         Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 2         Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 3         Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 4         Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# ..                     ...                                                ...
# 558  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 559  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 560  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 561  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 562  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
#
#                        Bus_Name                              Bus_Type  \
# 0    Shyamoli Paribahan Pvt Ltd                   VE A/C Seater (2+2)
# 1                  Express Line     Volvo 9600 A/C Semi Sleeper (2+2)
# 2                     Greenline                Volvo A/C Seater (2+2)
# 3          AdParameswar Travels            A/C Seater Push Back (2+3)
# 4    Shyamoli Paribahan Pvt Ltd                   VE A/C Seater (2+2)
# ..                          ...                                   ...
# 558  Snemita Parisheba (Bhunia)                       AC Seater (2+3)
# 559        Aradhana Bus Service            A/C Seater / Sleeper (2+2)
# 560        Aradhana Bus Service                   Non AC Seater (2+3)
# 561    Bengal Surface Transport            A/C Seater Push Back (2+3)
# 562           Aniruddha Travels  NON A/C Seater Push Back (2+3) (2+3)
#
#     Departure_Time Duration Reaching_Time Star_Rating    Price  \
# 0            23:30  05h 00m         04:30         4.6  INR 585
# 1            07:30  04h 25m         11:55         4.5  INR 649
# 2            06:45  05h 00m         11:45         4.4  INR 650
# 3            23:45  05h 15m         05:00         3.4      285
# 4            07:15  04h 45m         12:00         4.4  INR 450
# ..             ...      ...           ...         ...      ...
# 558          16:00  04h 10m         20:10         2.5  INR 370
# 559          03:10  03h 55m         07:05         2.4  INR 450
# 560          01:30  04h 00m         05:30         2.4  INR 350
# 561          23:59  04h 01m         04:00         2.1  INR 399
# 562          07:30  04h 50m         12:20         1.4  INR 279
#
#       Seat_Availability
# 0    26 Seats available
# 1     3 Seats available
# 2     2 Seats available
# 3    44 Seats available
# 4    28 Seats available
# ..                  ...
# 558  41 Seats available
# 559  31 Seats available
# 560   7 Seats available
# 561  20 Seats available
# 562  30 Seats available
#
# [563 rows x 10 columns]

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\WBSRTC.csv",index=False)

# %%
NBSTC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/travels/nbstc'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Kolkata to Siliguri, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Siliguri to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Siliguri to Darjeeling, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Kolkata to Raiganj, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Kolkata to Malda, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Raiganj to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Kolkata to Cooch Behar (West Bengal), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Malda to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Cooch Behar (West Bengal) to Berhampore (West Bengal), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Kolkata to Balurghat, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 5: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                Route_Name                                         Route_Link  \
# 0     Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 1     Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 2     Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 3     Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 4     Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# ..                    ...                                                ...
# 132  Kolkata to Balurghat  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 133  Kolkata to Balurghat  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 134  Kolkata to Balurghat  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 135  Kolkata to Balurghat  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 136  Kolkata to Balurghat  https://www.redbus.in/bus-tickets/kolkata-to-b...
#
#                                               Bus_Name  \
# 0    SBSTC-KOLKATA - SILIGURI - VOLVO - 20:05 (BEL ...
# 1                                            Easy Ride
# 2                                 Lokenath Bus Service
# 3                               AdLokenath Bus Service
# 4                           Shyamoli Paribahan Pvt Ltd
# ..                                                 ...
# 132                                New Dolphin Travels
# 133                               Padmanabha Paribahan
# 134                                Jio Dolphin Travels
# 135                              Shree Krishna Travels
# 136                           D.K. Traders (Tsa NBSTC)
#
#                                     Bus_Type Departure_Time Duration  \
# 0                      Volvo AC Seater (2+2)          20:05  13h 00m
# 1    Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  12h 55m
# 2    Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:45  12h 45m
# 3                 A/C Seater / Sleeper (2+1)          17:45  12h 45m
# 4    Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:15  13h 00m
# ..                                       ...            ...      ...
# 132           NON A/C Seater / Sleeper (2+2)          17:30  13h 30m
# 133               A/C Seater / Sleeper (2+2)          20:00  10h 30m
# 134           NON A/C Seater / Sleeper (2+2)          19:30  12h 30m
# 135           NON A/C Seater / Sleeper (2+2)          18:45  12h 45m
# 136                      Non AC Seater (2+3)          07:00  12h 00m
#
#     Reaching_Time Star_Rating     Price   Seat_Availability
# 0           09:05         3.9  INR 1210   5 Seats available
# 1           07:25         4.7  INR 5000  13 Seats available
# 2           07:30         4.7  INR 3500   9 Seats available
# 3           06:30         3.8  INR 1350  23 Seats available
# 4           08:15         4.7  INR 3780  20 Seats available
# ..            ...         ...       ...                 ...
# 132         07:00         2.5   INR 450  17 Seats available
# 133         06:30         2.5       475  50 Seats available
# 134         08:00         2.4   INR 400  26 Seats available
# 135         07:30         2.3   INR 350  13 Seats available
# 136         19:00         1.8   INR 340  10 Seats available
#
# [137 rows x 10 columns]

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\NBSTC.csv",index=False)

# %% [markdown]
# WBTC

# %%
driver = webdriver.Firefox()
driver.maximize_window()
time.sleep(4)
url = 'https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile'
driver.get(url)

full_details = []

max_page = 5
for page in range(1, max_page + 1):
    if page > 1:
        try:
            pagination_tab = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.XPATH, f"//div[text()='{page}']"))
            )
            driver.execute_script("arguments[0].click();", pagination_tab)
            time.sleep(3)
        except Exception as e:
            print(f"Issue while navigating to page number {page}: an the error is {e}")

    routes = driver.find_elements(By.CLASS_NAME, 'route')

    route_link = []
    route_names = []
    
    for a in routes:
        route_link.append(a.get_attribute('href'))
        route_names.append(a.text.strip())

    for link, name in zip(route_link, route_names):
        driver.get(link)
        time.sleep(2)

        try:
            view_buses_button = WebDriverWait(driver, 5).until(
                EC.element_to_be_clickable((By.XPATH, "//button[text()='View Buses']"))
            )
            driver.execute_script("arguments[0].click();", view_buses_button)
        except Exception as e:
            print(f"View Buses button is not found on page {name}, and error is {e}")

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        bus_name_elements = driver.find_elements(By.CLASS_NAME, "travels.lh-24.f-bold.d-color")
        bus_type_elements = driver.find_elements(By.CLASS_NAME, "bus-type.f-12.m-top-16.l-color.evBus")
        departing_time_elements = driver.find_elements(By.CLASS_NAME, "dp-time.f-19.d-color.f-bold")
        duration_elements = driver.find_elements(By.CLASS_NAME, "dur.l-color.lh-24")
        reaching_time_elements = driver.find_elements(By.CLASS_NAME, "bp-time.f-19.d-color.disp-Inline")
        star_rating_elements = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
        price_elements = driver.find_elements(By.CLASS_NAME, "fare.d-block")
        seat_availability_elements = driver.find_elements(By.XPATH, "//div[contains(@class, 'seat-left')]")

        for i in range(len(bus_name_elements)):
            bus_detail = {
                "Route_Name": name,
                "Route_Link": link,
                "Bus_Name": bus_name_elements[i].text,
                "Bus_Type": bus_type_elements[i].text,
                "Departure_Time": departing_time_elements[i].text,
                "Duration": duration_elements[i].text,
                "Reaching_Time": reaching_time_elements[i].text,
                "Star_Rating": star_rating_elements[i].text if i < len(star_rating_elements) else '0',
                "Price": price_elements[i].text,
                "Seat_Availability": seat_availability_elements[i].text if i < len(seat_availability_elements) else '0'
            }
            full_details.append(bus_detail)

df = pd.DataFrame(full_details)
print("Success")
display(df)
driver.quit()
# Out:
# View Buses button is not found on page Durgapur (West Bengal) to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Digha to Barasat (West Bengal), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Barasat (West Bengal) to Midnapore, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Midnapore to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Digha to Kolkata, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Kolkata to Digha, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Midnapore to Barasat (West Bengal), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Barasat (West Bengal) to Nandakumar (west bengal), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Barasat (West Bengal) to Kolaghat, and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# View Buses button is not found on page Barasat (West Bengal) to Contai (Kanthi), and error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 3: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Issue while navigating to page number 4: an the error is Message:
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:193:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:511:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16
#
# Success
#                                    Route_Name  \
# 0                        Midnapore to Kolkata
# 1                            Kolkata to Digha
# 2                            Kolkata to Digha
# 3                            Kolkata to Digha
# 4                            Kolkata to Digha
# ..                                        ...
# 192  Barasat (West Bengal) to Contai (Kanthi)
# 193  Barasat (West Bengal) to Contai (Kanthi)
# 194  Barasat (West Bengal) to Contai (Kanthi)
# 195  Barasat (West Bengal) to Contai (Kanthi)
# 196  Barasat (West Bengal) to Contai (Kanthi)
#
#                                             Route_Link  \
# 0    https://www.redbus.in/bus-tickets/midnapore-to...
# 1    https://www.redbus.in/bus-tickets/kolkata-to-d...
# 2    https://www.redbus.in/bus-tickets/kolkata-to-d...
# 3    https://www.redbus.in/bus-tickets/kolkata-to-d...
# 4    https://www.redbus.in/bus-tickets/kolkata-to-d...
# ..                                                 ...
# 192  https://www.redbus.in/bus-tickets/barasat-west...
# 193  https://www.redbus.in/bus-tickets/barasat-west...
# 194  https://www.redbus.in/bus-tickets/barasat-west...
# 195  https://www.redbus.in/bus-tickets/barasat-west...
# 196  https://www.redbus.in/bus-tickets/barasat-west...
#
#                        Bus_Name                           Bus_Type  \
# 0           Maa Bhabani Travels                Non AC Seater (2+3)
# 1    Shyamoli Paribahan Pvt Ltd                VE A/C Seater (2+2)
# 2                  Express Line  Volvo 9600 A/C Semi Sleeper (2+2)
# 3                     Greenline             Volvo A/C Seater (2+2)
# 4    Shyamoli Paribahan Pvt Ltd                VE A/C Seater (2+2)
# ..                          ...                                ...
# 192                City Express                    AC Seater (2+3)
# 193         SANTOSH BUS SERVICE                    AC Seater (2+3)
# 194           Snemita Parisheba                    AC Seater (2+3)
# 195        Aradhana Bus Service         A/C Seater / Sleeper (2+2)
# 196        Aradhana Bus Service                Non AC Seater (2+3)
#
#     Departure_Time Duration Reaching_Time Star_Rating    Price  \
# 0            07:05  03h 25m         10:30           0  INR 130
# 1            23:30  05h 00m         04:30         4.6  INR 585
# 2            07:30  04h 25m         11:55         4.5  INR 649
# 3            06:45  05h 00m         11:45         4.4  INR 650
# 4            07:15  04h 45m         12:00         4.4  INR 450
# ..             ...      ...           ...         ...      ...
# 192          05:35  03h 45m         09:20         3.4  INR 370
# 193          05:50  03h 40m         09:30         3.7      333
# 194          05:50  03h 40m         09:30         2.9  INR 420
# 195          02:30  03h 30m         06:00         2.4  INR 500
# 196          00:40  04h 20m         05:00         2.4  INR 350
#
#       Seat_Availability
# 0    52 Seats available
# 1    26 Seats available
# 2     3 Seats available
# 3     2 Seats available
# 4    28 Seats available
# ..                  ...
# 192  26 Seats available
# 193  40 Seats available
# 194  21 Seats available
# 195  43 Seats available
# 196   7 Seats available
#
# [197 rows x 10 columns]

# %%
df['Price']=pd.to_numeric(df['Price'].str.replace("INR",""))
df.to_csv(r"C:\Users\KISHORE\Desktop\Redbus Project\WBTC.csv",index=False)
